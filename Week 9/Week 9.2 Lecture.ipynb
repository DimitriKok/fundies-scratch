# %%
import pandas as pd

# %%
person = {
    "name" : ["James Bond", "Tim Cook", "Alan Smith"],
    "age" : [45, 65, 30],
    "city" : ["London", "LA", "NY"]
}

type(person)
# Out:
# dict

# %%
print(person)
# Out:
# {'name': ['James Bond', 'Tim Cook', 'Alan Smith'], 'age': [45, 65, 30], 'city': ['London', 'LA', 'NY']}

# %%
pd.DataFrame(person)
# Out:
#          name  age    city
# 0  James Bond   45  London
# 1    Tim Cook   65      LA
# 2  Alan Smith   30      NY

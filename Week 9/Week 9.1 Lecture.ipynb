# %%
import ipytest

# %%
ipytest.autoconfig()

# %%
# %%ipytest -qq
#
# # %% cell magice, it applies to the entire cell
# # ipytest, pythons most commly used test package
# # -qq, suppreses extra jibberish "extra quiet"
#
# def choose_hat(temp_in_C: float) -> str:
#     """determine appropriate head gear"""
#
#     if temp_in_C <= 10:
#         return "Winter Hat"
#     elif temp_in_C >= 27:
#         return "Summer Hat"
#     else:
#         return "No Hat"
#
# def test_choose_har():
#     assert choose_hat(10) == "Winter Hat"
#     assert choose_hat(25) == "No Hat"
#     assert choose_hat(5) == "Winter Hat"
#     assert choose_hat(32) == "Summer Hat"
# Out:
# UsageError: Cell magic `%%ipytest` not found.

# %%
# For loops

num = 0

for char in 'Hello World! I am working in Python':
    num += 1

print(f"The loop was executed {num} times")
# Out:
# The loop was executed 35 times

# %%
for x in range(5):
    if x == 2:
        continue
    print(x)
# Out:
# 0
# 1
# 3
# 4

# %% [markdown]
# # Class Exercises
# ## List Iteration
# - Design a Python function product_list(nums: list) -> float that returns the product of all numbers in the list (1 for empty list).
#
# - Design a Python function count_occurrences(items: list, target) -> int that returns how many times target appears in the list.
#
# - Design a Python function filter_by_prefix(words: list, prefix: str) -> list that returns a list of all words starting with the given prefix. In Python, if you have a string s, you can check if it starts with a prefix using s.startswith(prefix).

# %%
# %%ipytest -qq
#
# def product_list(nums: list) -> float:
#     total = 0
#     for x in nums:
#         total += x
#     return total
#
# a = [1,2,3,4,5]
#
# def testProductList():
#     assert product_list(a) == 15
#
# def count_occurences(items: list, target) -> float:
#     total = 0
#     for x in items:
#         if x == target:
#             total += 1
#     return total
#
# def testCountOccurences():
#     assert count_occurences(a, 5) == 1
#
#
# def filter_by_prefix(words: list, prefix: str) -> list:
#     total = []
#     for w in words:
#         if w.startswith(prefix):
#             total.append(w)
#     return total
#
# testWords = ["cat", "cast", "test"]
#
# def testFilter():
#     assert filter_by_prefix(testWords, "ca") == ["cat", "cast"]
# Out:
# ['cat', 'cast']
# ...                                                                                          [100%]

# %% [markdown]
# # Dictionary Iteration
# - Create a dictionary mapping student IDs to names. Add a new student, update a name, and remove a student.
#
# - Given a dictionary of conference sessions (as above), print all session IDs for sessions covering "AI".
#
# - Write a function that takes a dictionary of sessions and returns a list of all unique topics covered.

# %%
from dataclasses import dataclass

person = {
    "name" : ["James Bond", "Ethan Hunt"],
    "age" : ["45", "46"],
    "address" : ["007 Bond Street", "No Known Address"]
}

student = {}

@dataclass
class ConferenceSession:
    session_id: str
    title: str
    speaker: str
    topics: list[str]

session1 = ConferenceSession(
      "CS101",
      "Introduction to AI",
      "Dr. Martinez",
      ["AI", "Machine Learning"]
    )

# %%
student["id"] = 101
student["status"] = "Registered"

# %%
person["name"]

for keys, values in person.items():
    print(f"{keys}: {', '.join(map(str, values))}")
# Out:
# name: James Bond, Ethan Hunt
# age: 45, 46
# address: 007 Bond Street, no know address

# %%
for i in range(len(person["name"])):
    print(f"{person["name"][i]}: {person["address"][i]}")
# Out:
# James Bond: 007 Bond Street
# Ethan Hunt: No Known Address

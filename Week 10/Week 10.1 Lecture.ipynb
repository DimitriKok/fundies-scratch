# %%
import pandas as pd

# %%
sample_dict = {
    "code" : [8876, 5543, 7846, 2395],
    "quantity" : [1, 22, 4, 6],
    "price" : [0.5, 0.25, 1.99, 0.3]
}

# %%
df = pd.DataFrame(sample_dict)
df.head(2)
# Out:
#    code  quantity  price
# 0  8876         1   0.50
# 1  5543        22   0.25

# %%
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[df["age"] >= 18]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(f"Number of kids onboard: {len(df[df["age"] < 18])}")
# Out:
# Number of kids on board: 113

# %%
print(f"Number of adultd onboard: {len(df[df["age"] >= 18])}")
# Out:
# Number of adultd onboard: 601

# %%
df_adults =df[df["age"].between(18, 45)]
df_adults.reset_index(drop=True, inplace=True)

# %%
df_adults.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
df["embark_town"].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
# Adult, Male, Fare >= average, embarked from either Southampton or Queenstown
df[(df["sex"] == "male") & (df["age"].between(18, 45)) & (df["fare"] > df["fare"].mean()) & (df["embark_town"].isin(["Southampton", "Queenstown"])) & (df["sibsp"] == 0) & (df["class"] == "First") & (df["alive"] == "yes")]
# Out:
#     survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 23         1       1  male  28.0      0      0  35.5        S  First  man
#
#     adult_male deck  embark_town alive  alone
# 23        True    A  Southampton   yes   True
